# %%
import pandas as pd
import numpy as np
df=pd.read_csv(r"C:\Users\ARSHAD MALIK\system\Global_Superstore_Data.csv")

# %%
# import os

# %%
# os.chdir(r"C:\Users\ARSHAD MALIK\Music\Downloads")

# %%
# os.listdir(r"C:\Users\ARSHAD MALIK\Music\Downloads")

# %%
df.head(2)
# Out:
#    Row ID                  Order ID  Order Date   Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954  11-11-2014  11/13/2014   First Class
# 1   26341    IN-2014-JR162107-41675  02-05-2014  02-07-2014  Second Class
#
#     Customer ID  Customer Name    Segment  Postal Code           City  ...  \
# 0  AB-100151402  Aaron Bergman   Consumer      73120.0  Oklahoma City  ...
# 1     JR-162107  Justin Ritter  Corporate          NaN     Wollongong  ...
#
#     Product ID    Category Sub-Category  \
# 0  TEC-PH-5816  Technology       Phones
# 1  FUR-CH-5379   Furniture       Chairs
#
#                                 Product Name       Sales Quantity Discount  \
# 0                           Samsung Convoy 3    $221.98         2      0.0
# 1  Novimex Executive Leather Armchair, Black  $3,709.40         9      0.1
#
#       Profit Shipping Cost  Order Priority
# 0    $62.15          40.77            High
# 1  ($288.77)        923.63        Critical
#
# [2 rows x 24 columns]

# %%
df.shape
# Out:
# (51290, 24)

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Postal Code', 'City',
#        'State', 'Country', 'Region', 'Market', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %%
dff=df['Shipping Cost']>500

# %%
dff.value_counts()
# Out:
# False    51170
# True       120
# Name: Shipping Cost, dtype: int64

# %%
df[dff]
# Out:
#        Row ID                  Order ID  Order Date   Ship Date  \
# 1       26341    IN-2014-JR162107-41675  02-05-2014  02-07-2014
# 2       25330    IN-2014-CR127307-41929  10/17/2014  10/18/2014
# 3       13524   ES-2014-KM1637548-41667   1/28/2014   1/30/2014
# 4       47221   SG-2014-RH9495111-41948  11-05-2014  11-06-2014
# 5       22732    IN-2014-JM156557-41818   6/28/2014  07-01-2014
# ...       ...                       ...         ...         ...
# 46629   39399  CA-2013-SB20185140-41416   5/22/2013   5/26/2013
# 48570   46366   CA-2015-SV1081523-42361  12/23/2015  12/25/2015
# 48607   31784  CA-2012-SA20830140-41210  10/28/2012  10/30/2012
# 49493   36178  CA-2015-TB21175140-42311  11-03-2015  11-06-2015
# 50010   38540  CA-2015-TP21415140-42234   8/18/2015   8/23/2015
#
#             Ship Mode   Customer ID     Customer Name      Segment  \
# 1        Second Class     JR-162107     Justin Ritter    Corporate
# ...

# %%
pd.isnull(df["Segment"])
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 51285    False
# 51286    False
# 51287    False
# 51288    False
# 51289    False
# Name: Segment, Length: 51290, dtype: bool

# %%
pd.isnull(df["Segment"]).sum()
# Out:
# 0

# %%
pd.notnull(df["Segment"]).sum()
# Out:
# 51290

# %%
pd.isnull(df["Country"]).sum()
# Out:
# 0

# %%
pd.notnull(df["Country"]).sum()
# Out:
# 51290

# %%
pd.isnull(df["Region"]).sum()
# Out:
# 0

# %%
pd.notnull(df["Region"]).sum()
# Out:
# 51290

# %%
pd.notnull(df["Sub-Category"]).sum()
# Out:
# 51290

# %%
pd.notnull(df["Category"]).sum()
# Out:
# 51290

# %%
pd.notnull(df["Market"]).sum()
# Out:
# 51290

# %%
df[dff].head()
# Out:
#    Row ID                 Order ID  Order Date   Ship Date     Ship Mode  \
# 1   26341   IN-2014-JR162107-41675  02-05-2014  02-07-2014  Second Class
# 2   25330   IN-2014-CR127307-41929  10/17/2014  10/18/2014   First Class
# 3   13524  ES-2014-KM1637548-41667   1/28/2014   1/30/2014   First Class
# 4   47221  SG-2014-RH9495111-41948  11-05-2014  11-06-2014      Same Day
# 5   22732   IN-2014-JM156557-41818   6/28/2014  07-01-2014  Second Class
#
#   Customer ID     Customer Name      Segment  Postal Code        City  ...  \
# 1   JR-162107     Justin Ritter    Corporate          NaN  Wollongong  ...
# 2   CR-127307      Craig Reiter     Consumer          NaN    Brisbane  ...
# 3  KM-1637548  Katherine Murray  Home Office          NaN      Berlin  ...
# 4  RH-9495111       Rick Hansen     Consumer          NaN       Dakar  ...
# 5   JM-156557       Jim Mitchum    Corporate          NaN      Sydney  ...
#
#     Product ID    Category Sub-Category  \
# ...

# %%
df1=df[dff]

# %%
df1
# Out:
#        Row ID                  Order ID  Order Date   Ship Date  \
# 1       26341    IN-2014-JR162107-41675  02-05-2014  02-07-2014
# 2       25330    IN-2014-CR127307-41929  10/17/2014  10/18/2014
# 3       13524   ES-2014-KM1637548-41667   1/28/2014   1/30/2014
# 4       47221   SG-2014-RH9495111-41948  11-05-2014  11-06-2014
# 5       22732    IN-2014-JM156557-41818   6/28/2014  07-01-2014
# ...       ...                       ...         ...         ...
# 46629   39399  CA-2013-SB20185140-41416   5/22/2013   5/26/2013
# 48570   46366   CA-2015-SV1081523-42361  12/23/2015  12/25/2015
# 48607   31784  CA-2012-SA20830140-41210  10/28/2012  10/30/2012
# 49493   36178  CA-2015-TB21175140-42311  11-03-2015  11-06-2015
# 50010   38540  CA-2015-TP21415140-42234   8/18/2015   8/23/2015
#
#             Ship Mode   Customer ID     Customer Name      Segment  \
# 1        Second Class     JR-162107     Justin Ritter    Corporate
# ...

# %%
df1.shape
# Out:
# (120, 24)

# %%
df2=df1["Category"]=="Technology"

# %%
df3=df1[df2]

# %%
df4=df3['Country']=='India'

# %%
df5=df3[df4] #list of Order ID's where the Indian customer's have bought the things under the category 'Technology' after paying the Shipping Cost more than 500

# %%
df5['Order ID']
# Out:
# 41    IN-2015-BF1100558-42319
# 48    IN-2015-SW2027558-42125
# 55    IN-2013-SG2047058-41424
# 90    IN-2013-GP1474058-41419
# Name: Order ID, dtype: object

# %%
#list of Order ID's where the Indian customer's have bought the things under the category 'Technology' after paying the Shipping Cost more than 500.
cf=(df['Country']== 'India') & (df['Category']=='Technology')&(df['Shipping Cost']>500)

# %%
df6=df[cf]

# %%
df6
# Out:
#     Row ID                 Order ID  Order Date   Ship Date       Ship Mode  \
# 41   29272  IN-2015-BF1100558-42319  11-11-2015  11/15/2015  Standard Class
# 48   28701  IN-2015-SW2027558-42125  05-01-2015  05-01-2015        Same Day
# 55   29047  IN-2013-SG2047058-41424   5/30/2013   5/31/2013     First Class
# 90   29600  IN-2013-GP1474058-41419   5/25/2013   5/28/2013    Second Class
#
#    Customer ID     Customer Name      Segment  Postal Code        City  ...  \
# 41  BF-1100558       Barry Franz  Home Office          NaN   Gorakhpur  ...
# 48  SW-2027558  Scott Williamson     Consumer          NaN  Jamshedpur  ...
# 55  SG-2047058      Sheri Gordon     Consumer          NaN      Bhopal  ...
# 90  GP-1474058       Guy Phonely    Corporate          NaN       Delhi  ...
#
#      Product ID    Category Sub-Category  \
# 41  TEC-PH-5269  Technology       Phones
# 48  TEC-MA-5007  Technology     Machines
# 55  TEC-CO-4590  Technology      Copiers
# ...

# %%
df6['Order ID']
# Out:
# 41    IN-2015-BF1100558-42319
# 48    IN-2015-SW2027558-42125
# 55    IN-2013-SG2047058-41424
# 90    IN-2013-GP1474058-41419
# Name: Order ID, dtype: object

# %%
df
# Out:
#        Row ID                  Order ID  Order Date   Ship Date  \
# 0       40098  CA-2014-AB10015140-41954  11-11-2014  11/13/2014
# 1       26341    IN-2014-JR162107-41675  02-05-2014  02-07-2014
# 2       25330    IN-2014-CR127307-41929  10/17/2014  10/18/2014
# 3       13524   ES-2014-KM1637548-41667   1/28/2014   1/30/2014
# 4       47221   SG-2014-RH9495111-41948  11-05-2014  11-06-2014
# ...       ...                       ...         ...         ...
# 51285   29002   IN-2015-KE1642066-42174   6/19/2015   6/19/2015
# 51286   34337  US-2014-ZD21925140-41765  05-06-2014  05-10-2014
# 51287   31315  CA-2012-ZD21925140-41147   8/26/2012   8/31/2012
# 51288    9596   MX-2013-RB1979518-41322   2/17/2013   2/21/2013
# 51289    6147   MX-2013-MC1810093-41416   5/22/2013   5/26/2013
#
#             Ship Mode   Customer ID       Customer Name      Segment  \
# 0         First Class  AB-100151402       Aaron Bergman     Consumer
# ...

# %%
#people from the State 'Karnataka' have bought the things under the category 'Technology'
pk=(df['Country']== 'India') & (df['Category']=='Technology')&(df['State']=='Karnataka')

# %%
df[pk]
# Out:
#        Row ID                 Order ID  Order Date   Ship Date  \
# 408     27724  IN-2015-CY1274558-42300  10/23/2015  10/25/2015
# 782     27579  IN-2015-JW1522058-42101  04-07-2015  04-12-2015
# 1957    22906  IN-2014-RA1928558-41863  08-12-2014   8/16/2014
# 2364    28779  IN-2014-BO1135058-41783   5/24/2014   5/30/2014
# 3200    22204  IN-2014-CM1238558-41755   4/26/2014   4/28/2014
# 5030    28814  IN-2015-MK1816058-42330  11/22/2015  11/26/2015
# 5132    28511  IN-2012-AH1046558-41059   5/30/2012   5/30/2012
# 5378    21739  IN-2014-TC2147558-41753   4/24/2014   4/26/2014
# 5572    24372  IN-2015-Co1264058-42326  11/18/2015  11/22/2015
# 7304    22905  IN-2014-RA1928558-41863  08-12-2014   8/16/2014
# 12782   21980  IN-2013-MA1756058-41275  01-01-2013  01-06-2013
# 12996   29865  IN-2013-MH1745558-41590  11-12-2013  11/17/2013
# 14278   22904  IN-2014-RA1928558-41863  08-12-2014   8/16/2014
# 16364   23769  IN-2013-TB2152058-41430  06-05-2013  06-10-2013
# ...

# %%
cnpk=df[pk]

# %%
cnpk['Customer Name']
# Out:
# 408              Craig Yedwab
# 782                 Jane Waco
# 1957             Ralph Arnett
# 2364            Bill Overfelt
# 3200     Christopher Martinez
# 5030             Mike Kennedy
# 5132                 Amy Hunt
# 5378             Tony Chapman
# 5572               Corey-Lock
# 7304             Ralph Arnett
# 12782            Matt Abelman
# 12996           Mark Hamilton
# 14278            Ralph Arnett
# 16364         Tracy Blumstein
# 16877           Odella Nelson
# 17155              Corey-Lock
# 18314              Corey-Lock
# 18733    Christopher Martinez
# 21482          Pauline Webber
# 21675          Lena Creighton
# 35956             Alyssa Tate
# Name: Customer Name, dtype: object

# %%
#list of countries where the 'Profit' and 'Shipping Cost' are greater than or equal to 200 and 300 respectively.

# %%
df.shape
# Out:
# (51290, 24)

# %%
df['Shipping Cost']>300
# Out:
# 0        False
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 51285    False
# 51286    False
# 51287    False
# 51288    False
# 51289    False
# Name: Shipping Cost, Length: 51290, dtype: bool

# %%
df[['Profit','Shipping Cost']]
# Out:
#           Profit  Shipping Cost
# 0        $62.15          40.770
# 1      ($288.77)        923.630
# 2       $919.97         915.490
# 3       ($96.54)        910.160
# 4       $311.52         903.040
# ...          ...            ...
# 51285     $4.50           1.010
# 51286     $3.34           1.930
# 51287     $2.48           1.580
# 51288     $2.40           1.003
# 51289     $1.80           1.002
#
# [51290 rows x 2 columns]

# %%
df['Profit'].dtype
# Out:
# dtype('O')

# %%
df.dtypes
# Out:
# Row ID              int64
# Order ID           object
# Order Date         object
# Ship Date          object
# Ship Mode          object
# Customer ID        object
# Customer Name      object
# Segment            object
# Postal Code       float64
# City               object
# State              object
# Country            object
# Region             object
# Market             object
# Product ID         object
# Category           object
# Sub-Category       object
# Product Name       object
# Sales              object
# Quantity            int64
# Discount          float64
# Profit             object
# Shipping Cost     float64
# Order Priority     object
# dtype: object

# %%
# v1=lambda x:float(x[1:-1])
# df.Profit=df.Profit.apply(v1)

# %%
x=df['Profit']

# %%
x=pd.to_numeric(x.replace('[^10-9\.-]','',regex=True))
x
# Out:
# 0         62.15
# 1        288.77
# 2        919.97
# 3         96.54
# 4        311.52
#           ...
# 51285      4.50
# 51286      3.34
# 51287      2.48
# 51288      2.40
# 51289      1.80
# Name: Profit, Length: 51290, dtype: float64

# %%
xf=pd.DataFrame(x)
xf
# Out:
#        Profit
# 0       62.15
# 1      288.77
# 2      919.97
# 3       96.54
# 4      311.52
# ...       ...
# 51285    4.50
# 51286    3.34
# 51287    2.48
# 51288    2.40
# 51289    1.80
#
# [51290 rows x 1 columns]

# %%
df
# Out:
#        Row ID                  Order ID  Order Date   Ship Date  \
# 0       40098  CA-2014-AB10015140-41954  11-11-2014  11/13/2014
# 1       26341    IN-2014-JR162107-41675  02-05-2014  02-07-2014
# 2       25330    IN-2014-CR127307-41929  10/17/2014  10/18/2014
# 3       13524   ES-2014-KM1637548-41667   1/28/2014   1/30/2014
# 4       47221   SG-2014-RH9495111-41948  11-05-2014  11-06-2014
# ...       ...                       ...         ...         ...
# 51285   29002   IN-2015-KE1642066-42174   6/19/2015   6/19/2015
# 51286   34337  US-2014-ZD21925140-41765  05-06-2014  05-10-2014
# 51287   31315  CA-2012-ZD21925140-41147   8/26/2012   8/31/2012
# 51288    9596   MX-2013-RB1979518-41322   2/17/2013   2/21/2013
# 51289    6147   MX-2013-MC1810093-41416   5/22/2013   5/26/2013
#
#             Ship Mode   Customer ID       Customer Name      Segment  \
# 0         First Class  AB-100151402       Aaron Bergman     Consumer
# ...

# %%
df.update(xf)

# %%
df
# Out:
#        Row ID                  Order ID  Order Date   Ship Date  \
# 0       40098  CA-2014-AB10015140-41954  11-11-2014  11/13/2014
# 1       26341    IN-2014-JR162107-41675  02-05-2014  02-07-2014
# 2       25330    IN-2014-CR127307-41929  10/17/2014  10/18/2014
# 3       13524   ES-2014-KM1637548-41667   1/28/2014   1/30/2014
# 4       47221   SG-2014-RH9495111-41948  11-05-2014  11-06-2014
# ...       ...                       ...         ...         ...
# 51285   29002   IN-2015-KE1642066-42174   6/19/2015   6/19/2015
# 51286   34337  US-2014-ZD21925140-41765  05-06-2014  05-10-2014
# 51287   31315  CA-2012-ZD21925140-41147   8/26/2012   8/31/2012
# 51288    9596   MX-2013-RB1979518-41322   2/17/2013   2/21/2013
# 51289    6147   MX-2013-MC1810093-41416   5/22/2013   5/26/2013
#
#             Ship Mode   Customer ID       Customer Name      Segment  \
# 0         First Class  AB-100151402       Aaron Bergman     Consumer
# ...

# %%
ps=(df['Profit']>200) & (df['Shipping Cost']>300)

# %%
dc=df[ps]

# %%
dc
# Out:
#        Row ID                  Order ID  Order Date   Ship Date  \
# 1       26341    IN-2014-JR162107-41675  02-05-2014  02-07-2014
# 2       25330    IN-2014-CR127307-41929  10/17/2014  10/18/2014
# 4       47221   SG-2014-RH9495111-41948  11-05-2014  11-06-2014
# 5       22732    IN-2014-JM156557-41818   6/28/2014  07-01-2014
# 6       30570   IN-2012-TS2134092-41219  11-06-2012  11-08-2012
# ...       ...                       ...         ...         ...
# 50010   38540  CA-2015-TP21415140-42234   8/18/2015   8/23/2015
# 50471   39309  CA-2015-TB21625140-42150   5/26/2015   5/26/2015
# 50915   36004  CA-2015-WB21850140-42185   6/30/2015  07-01-2015
# 51151   34367  CA-2012-YC21895140-41229  11/16/2012  11/21/2012
# 51152   32050  CA-2014-YC21895140-41737  04-08-2014  04-10-2014
#
#             Ship Mode   Customer ID   Customer Name    Segment  Postal Code  \
# 1        Second Class     JR-162107   Justin Ritter  Corporate          NaN
# ...

# %%
dc['Country']
# Out:
# 1            Australia
# 2            Australia
# 4              Senegal
# 5            Australia
# 6          New Zealand
#              ...
# 50010    United States
# 50471    United States
# 50915    United States
# 51151    United States
# 51152    United States
# Name: Country, Length: 361, dtype: object

# %%
# let's create a dataframe of type object and convert it into a float or integer
cf=pd.DataFrame({ 'profit': ['44$','67$','89$','95$','23$']})
cf
# Out:
#   profit
# 0    44$
# 1    67$
# 2    89$
# 3    95$
# 4    23$

# %%
cf['profit'].dtypes
# Out:
# dtype('O')

# %%
cf['profit']=pd.to_numeric(x.replace('[^10-9\.-]','',regex=True))

# %%
cf['profit']
# Out:
# 0     62.15
# 1    288.77
# 2    919.97
# 3     96.54
# 4    311.52
# Name: profit, dtype: float64

# %%
#list of Indian states where the people have purchased the things under the category Technology.
df
# Out:
#        Row ID                  Order ID  Order Date   Ship Date  \
# 0       40098  CA-2014-AB10015140-41954  11-11-2014  11/13/2014
# 1       26341    IN-2014-JR162107-41675  02-05-2014  02-07-2014
# 2       25330    IN-2014-CR127307-41929  10/17/2014  10/18/2014
# 3       13524   ES-2014-KM1637548-41667   1/28/2014   1/30/2014
# 4       47221   SG-2014-RH9495111-41948  11-05-2014  11-06-2014
# ...       ...                       ...         ...         ...
# 51285   29002   IN-2015-KE1642066-42174   6/19/2015   6/19/2015
# 51286   34337  US-2014-ZD21925140-41765  05-06-2014  05-10-2014
# 51287   31315  CA-2012-ZD21925140-41147   8/26/2012   8/31/2012
# 51288    9596   MX-2013-RB1979518-41322   2/17/2013   2/21/2013
# 51289    6147   MX-2013-MC1810093-41416   5/22/2013   5/26/2013
#
#             Ship Mode   Customer ID       Customer Name      Segment  \
# 0         First Class  AB-100151402       Aaron Bergman     Consumer
# ...

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Postal Code', 'City',
#        'State', 'Country', 'Region', 'Market', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %%
ti=(df['Category']=='Technology') & (df['Country']=='India')

# %%
c=df[ti]

# %%
c['State']
# Out:
# 41              Haryana
# 48            Jharkhand
# 55       Madhya Pradesh
# 90                Delhi
# 130             Gujarat
#               ...
# 39631            Kerala
# 40262            Punjab
# 42345             Bihar
# 43976         Telangana
# 51172        Tamil Nadu
# Name: State, Length: 354, dtype: object

# %%
# Find the overall rank of India where the 'Profit' is maximum under the category 'Technology'

# %%
ti=(df['Category']=='Technology') & (df['Country']=='India')

# %%
df[ti]
# Out:
#        Row ID                 Order ID  Order Date   Ship Date  \
# 41      29272  IN-2015-BF1100558-42319  11-11-2015  11/15/2015
# 48      28701  IN-2015-SW2027558-42125  05-01-2015  05-01-2015
# 55      29047  IN-2013-SG2047058-41424   5/30/2013   5/31/2013
# 90      29600  IN-2013-GP1474058-41419   5/25/2013   5/28/2013
# 130     23880  IN-2014-SV2081558-41968  11/25/2014  11/27/2014
# ...       ...                      ...         ...         ...
# 39631   21504  IN-2013-JR1570058-41441   6/16/2013   6/22/2013
# 40262   21321  IN-2014-GZ1447058-41721   3/23/2014   3/27/2014
# 42345   21930  IN-2015-CR1282058-42294  10/17/2015  10/21/2015
# 43976   26138  IN-2015-LD1700558-42101  04-07-2015  04-11-2015
# 51172   29523  IN-2014-AS1013558-41817   6/27/2014  07-03-2014
#
#             Ship Mode Customer ID     Customer Name      Segment  Postal Code  \
# 41     Standard Class  BF-1100558       Barry Franz  Home Office          NaN
# ...

# %%
df[ti].rank()
# Out:
#        Row ID  Order ID  Order Date  Ship Date  Ship Mode  Customer ID  \
# 41      322.0     252.0       163.5      156.0      242.5         46.0
# 48      303.0     346.0        30.0       29.5       53.0        326.0
# 55      316.0     145.5       271.5      259.0       23.5        314.5
# 90      337.0      99.0       265.0      253.0       95.0        150.0
# 130     126.0     223.0       186.5      178.0       23.5        322.0
# ...       ...       ...         ...        ...        ...          ...
# 39631    34.0     107.0       280.0      275.0      242.5        188.0
# 40262    29.0     181.5       236.5      224.5      242.5        154.5
# 42345    48.0     271.0       132.0      126.0      242.5         89.0
# 43976   210.0     317.5        25.0       21.5      242.5        220.5
# 51172   333.0     160.5       296.5       55.5      242.5         33.0
#
#        Customer Name  Segment  Postal Code   City  ...  Product ID  Category  \
# ...

# %%
# Display the data with min, max, average and std of 'Profit' & 'Sales' for each Sub-Category under each Category"
