# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\ARSHAD MALIK\system\student.csv")

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df['total score']=df['math score']+df['reading score']+df['writing score']

# %%
df['total score']
# Out:
# 0      218
# 1      247
# 2      278
# 3      148
# 4      229
#       ...
# 995    282
# 996    172
# 997    195
# 998    223
# 999    249
# Name: total score, Length: 1000, dtype: int64

# %%
df['percentage']=(df['total score']/300)*100

# %%
df['percentage']
# Out:
# 0      72.666667
# 1      82.333333
# 2      92.666667
# 3      49.333333
# 4      76.333333
#          ...
# 995    94.000000
# 996    57.333333
# 997    65.000000
# 998    74.333333
# 999    83.000000
# Name: percentage, Length: 1000, dtype: float64

# %%
def grad(x):
    if x>=80:
        return 'A'
    elif x>=70 and x<80:
        return 'B'
    elif x>=60 and x<70:
        return 'C'
    elif x>=50 and x<60:
        return 'D'
    else:
        return 'E'
df['grade']=df['percentage'].apply(grad)

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
data=pd.read_csv(r"C:\computer\amazon_alexa.tsv", delimiter="\t")

# %%
data.shape
# Out:
# (3150, 5)

# %%
data.head()
# Out:
#    rating       date         variation  \
# 0       5  31-Jul-18  Charcoal Fabric
# 1       5  31-Jul-18  Charcoal Fabric
# 2       4  31-Jul-18    Walnut Finish
# 3       5  31-Jul-18  Charcoal Fabric
# 4       5  31-Jul-18  Charcoal Fabric
#
#                                     verified_reviews  feedback
# 0                                      Love my Echo!         1
# 1                                          Loved it!         1
# 2  Sometimes while playing a game, you can answer...         1
# 3  I have had a lot of fun with this thing. My 4 ...         1
# 4                                              Music         1

# %%
data.columns
# Out:
# Index(['rating', 'date', 'variation', 'verified_reviews', 'feedback'], dtype='object')

# %%
data.isnull().sum()
# Out:
# rating              0
# date                0
# variation           0
# verified_reviews    0
# feedback            0
# dtype: int64

# %%
data.describe()
# Out:
#             rating     feedback
# count  3150.000000  3150.000000
# mean      4.463175     0.918413
# std       1.068506     0.273778
# min       1.000000     0.000000
# 25%       4.000000     1.000000
# 50%       5.000000     1.000000
# 75%       5.000000     1.000000
# max       5.000000     1.000000

# %%
data.describe(include="object")
# Out:
#              date   variation verified_reviews
# count        3150        3150             3150
# unique         77          16             2301
# top     30-Jul-18  Black  Dot
# freq         1603         516               79

# %%
data['variation'].value_counts()
# Out:
# Black  Dot                      516
# Charcoal Fabric                 430
# Configuration: Fire TV Stick    350
# Black  Plus                     270
# Black  Show                     265
# Black                           261
# Black  Spot                     241
# White  Dot                      184
# Heather Gray Fabric             157
# White  Spot                     109
# White                            91
# Sandstone Fabric                 90
# White  Show                      85
# White  Plus                      78
# Oak Finish                       14
# Walnut Finish                     9
# Name: variation, dtype: int64

# %% [markdown]
# # sentiment analysis

# %%
#sentiment analysis(subjectivity and polarity)

# %%
import pandas as pd 
from textblob import TextBlob

# %%
data=pd.read_csv(r"C:\computer\amazon_alexa.tsv", delimiter="\t")

# %%
data.shape
# Out:
# (3150, 5)

# %%
data.head(5)
# Out:
#    rating       date         variation  \
# 0       5  31-Jul-18  Charcoal Fabric
# 1       5  31-Jul-18  Charcoal Fabric
# 2       4  31-Jul-18    Walnut Finish
# 3       5  31-Jul-18  Charcoal Fabric
# 4       5  31-Jul-18  Charcoal Fabric
#
#                                     verified_reviews  feedback
# 0                                      Love my Echo!         1
# 1                                          Loved it!         1
# 2  Sometimes while playing a game, you can answer...         1
# 3  I have had a lot of fun with this thing. My 4 ...         1
# 4                                              Music         1

# %%
data['length']=data['verified_reviews'].apply(len)

# %%
data.head()
# Out:
#    rating       date         variation  \
# 0       5  31-Jul-18  Charcoal Fabric
# 1       5  31-Jul-18  Charcoal Fabric
# 2       4  31-Jul-18    Walnut Finish
# 3       5  31-Jul-18  Charcoal Fabric
# 4       5  31-Jul-18  Charcoal Fabric
#
#                                     verified_reviews  feedback  length
# 0                                      Love my Echo!         1      13
# 1                                          Loved it!         1       9
# 2  Sometimes while playing a game, you can answer...         1     195
# 3  I have had a lot of fun with this thing. My 4 ...         1     172
# 4                                              Music         1       5

# %%
# text polarity says sentiment is positive negative or neutral speaking good or bad in reviews

# %%
#lets calculate polarity of the reviews
def get_polarity(text):
    textblob=TextBlob(str(text.encode('utf-8')))
    pol=textblob.sentiment.polarity
    return pol
# let's apply it to a function
data['polarity']=data['verified_reviews'].apply(get_polarity)

# %%
data.head()
# Out:
#    rating       date         variation  \
# 0       5  31-Jul-18  Charcoal Fabric
# 1       5  31-Jul-18  Charcoal Fabric
# 2       4  31-Jul-18    Walnut Finish
# 3       5  31-Jul-18  Charcoal Fabric
# 4       5  31-Jul-18  Charcoal Fabric
#
#                                     verified_reviews  feedback  length  \
# 0                                      Love my Echo!         1      13
# 1                                          Loved it!         1       9
# 2  Sometimes while playing a game, you can answer...         1     195
# 3  I have had a lot of fun with this thing. My 4 ...         1     172
# 4                                              Music         1       5
#
#    polarity
# 0     0.625
# 1     0.875
# 2    -0.100
# 3     0.350
# 4     0.000

# %% [markdown]
# ### subjectivity

# %% [markdown]
# subjectivity refers how strong are your opinion how much positive or negative

# %%
# let's calculate subjectivity of reviews
def get_subjectivity(text):
    textblob=TextBlob(str(text.encode('utf-8')))
    subj=textblob.sentiment.subjectivity
    return subj
#let's apply function by creating new column
data['subjectivity']=data['verified_reviews'].apply(get_subjectivity)

# %%
data.head()
# Out:
#    rating       date         variation  \
# 0       5  31-Jul-18  Charcoal Fabric
# 1       5  31-Jul-18  Charcoal Fabric
# 2       4  31-Jul-18    Walnut Finish
# 3       5  31-Jul-18  Charcoal Fabric
# 4       5  31-Jul-18  Charcoal Fabric
#
#                                     verified_reviews  feedback  length  \
# 0                                      Love my Echo!         1      13
# 1                                          Loved it!         1       9
# 2  Sometimes while playing a game, you can answer...         1     195
# 3  I have had a lot of fun with this thing. My 4 ...         1     172
# 4                                              Music         1       5
#
#    polarity  subjectivity
# 0     0.625        0.6000
# 1     0.875        0.8000
# 2    -0.100        0.5125
# 3     0.350        0.4500
# 4     0.000        0.0000

# %%
data[["length","polarity","subjectivity"]].describe()
# Out:
#             length     polarity  subjectivity
# count  3150.000000  3150.000000   3150.000000
# mean    132.049524     0.349792      0.528922
# std     182.099952     0.303362      0.256324
# min       1.000000    -1.000000      0.000000
# 25%      30.000000     0.123852      0.419196
# 50%      74.000000     0.350000      0.585000
# 75%     165.000000     0.533333      0.695486
# max    2851.000000     1.000000      1.000000

# %% [markdown]
# # finding words, character and punctuation marks

# %%
data=pd.read_csv(r"C:\computer\amazon_alexa.tsv", delimiter="\t")

# %%
data.shape
# Out:
# (3150, 5)

# %%
data['char_count']=data['verified_reviews'].apply(len)

# %%
data['word_count']=data['verified_reviews'].apply(lambda x:len(x.split()))

# %%
#calculate word density
data['word_density']=data['char_count']/(data['word_count']+1)

# %%
import string

# %%
punctuation=string.punctuation

# %%
punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
data['punctuation_count']=data['verified_reviews'].apply(lambda x:len("".join(_ for _ in x if _ in punctuation)))

# %%
data.head()
# Out:
#    rating       date         variation  \
# 0       5  31-Jul-18  Charcoal Fabric
# 1       5  31-Jul-18  Charcoal Fabric
# 2       4  31-Jul-18    Walnut Finish
# 3       5  31-Jul-18  Charcoal Fabric
# 4       5  31-Jul-18  Charcoal Fabric
#
#                                     verified_reviews  feedback  char_count  \
# 0                                      Love my Echo!         1          13
# 1                                          Loved it!         1           9
# 2  Sometimes while playing a game, you can answer...         1         195
# 3  I have had a lot of fun with this thing. My 4 ...         1         172
# 4                                              Music         1           5
#
#    word_count  word_density  punctuation_count
# 0           3      3.250000                  1
# 1           2      3.000000                  1
# 2          38      5.000000                  3
# 3          34      4.914286                  4
# ...

# %%
data.describe()
# Out:
#             rating     feedback   char_count   word_count  word_density  \
# count  3150.000000  3150.000000  3150.000000  3150.000000   3150.000000
# mean      4.463175     0.918413   132.049524    25.293016      4.605345
# std       1.068506     0.273778   182.099952    34.584971      1.134737
# min       1.000000     0.000000     1.000000     0.000000      0.500000
# 25%       4.000000     1.000000    30.000000     6.000000      4.269231
# 50%       5.000000     1.000000    74.000000    14.000000      4.805665
# 75%       5.000000     1.000000   165.000000    32.000000      5.207974
# max       5.000000     1.000000  2851.000000   526.000000     32.500000
#
#        punctuation_count
# count        3150.000000
# mean            3.887937
# std             5.762348
# min             0.000000
# 25%             1.000000
# 50%             2.000000
# 75%             5.000000
# max           121.000000

# %%
data[['char_count','word_count','word_density','punctuation_count']].describe()
# Out:
#         char_count   word_count  word_density  punctuation_count
# count  3150.000000  3150.000000   3150.000000        3150.000000
# mean    132.049524    25.293016      4.605345           3.887937
# std     182.099952    34.584971      1.134737           5.762348
# min       1.000000     0.000000      0.500000           0.000000
# 25%      30.000000     6.000000      4.269231           1.000000
# 50%      74.000000    14.000000      4.805665           2.000000
# 75%     165.000000    32.000000      5.207974           5.000000
# max    2851.000000   526.000000     32.500000         121.000000

# %%
# !pip install nltk
# Out:
# ...
# WARNING: You are using pip version 21.1.1; however, version 21.1.2 is available.
# You should consider upgrading via the 'c:\users\arshad malik\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.
# ...

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Error loading punkt: <urlopen error [Errno 11001]
# [nltk_data]     getaddrinfo failed>
# False

# %%
from textblob import TextBlob
text= ("codespeedy is aprogramming blog"
      "blog post contain articles tutorials and programs on css html and javascript")
tb=TextBlob(text)
print(tb.tags)
# Out:
# [('codespeedy', 'NN'), ('is', 'VBZ'), ('aprogramming', 'VBG'), ('blogblog', 'NN'), ('post', 'NN'), ('contain', 'NN'), ('articles', 'NNS'), ('tutorials', 'NNS'), ('and', 'CC'), ('programs', 'NNS'), ('on', 'IN'), ('css', 'NN'), ('html', 'NN'), ('and', 'CC'), ('javascript', 'NN')]

# %%
# lets create parts of speech dictionary
pos_dic={
    'noun':['NN','NNS','NNP','NNPS'],
    'pronoun':['PRP','PRP$','WP','WP$'],
    'verb':['VB','VBD','VBG','VBN','VBN','VBZ'],
    'adjective':['JJ','JJR','JJS'],
    'adverb':['RB','RBR','RBS','WRB']
    
}
#function to check and get the part of speech tag count of words in a given sentence
def pos_check(x,flag):
    cnt=0
    try:
        wiki=TextBlob(x)
        for tup in wiki.tags:
            ppo=list(tup)[1]
            if ppo in pos_dic[flag]:
                cnt+=1
    except:
        pass
    return cnt

# %%
pos_check(text,"noun")
# Out:
# 10

# %%
data['noun_count']=data['verified_reviews'].apply(lambda x: pos_check(x, "noun"))

# %%
data['verb_count']=data['verified_reviews'].apply(lambda x: pos_check(x, "verb"))

# %%
data[['noun_count','verb_count']].describe()
# Out:
#         noun_count   verb_count
# count  3150.000000  3150.000000
# mean      5.945397     4.108571
# std       8.222776     5.890147
# min       0.000000     0.000000
# 25%       1.000000     1.000000
# 50%       3.000000     2.000000
# 75%       7.000000     5.000000
# max     137.000000    82.000000
